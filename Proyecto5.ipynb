# %%
from google.colab import drive
drive.mount("/content/drive/")

# Verificar que la carpeta existe
# !ls "/content/drive/MyDrive/"

# Instalar import-ipynb
# !pip install import-ipynb

# Cambiar a la carpeta correcta
# %cd "/content/drive/MyDrive/Colab Notebooks/Trabajos U/"

# Importar archivos IPYNB
import import_ipynb
import Proyecto2  # Importar funciones desde Proyecto2.ipynb
import Proyecto3  # Importar funciones desde Proyecto3.ipynb
import Proyecto4
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
#  2024_1_Automatas_Lenguajes_Formales
# '2.-GFPI-F-019 Guías de Aprendizaje.docx'
# '4 Matemáticas 2021 (1).gdoc'
# '4 Matemáticas 2021.gdoc'
#  Ambiental.gdoc
# 'Análisis del Macroentorno.docx'
# 'Análisis del Macroentorno.gdoc'
# 'Base de datos.gdoc'
#  Ciclotrón.gslides
# 'Colab Notebooks'
#  comprobante.pdf
# 'contraseñas plataforma integra.gdoc'
#  convocatoria.png
# 'Copia de calculo escencial.pdf'
# 'Copia de Documento Cancelacion.gdoc'
# 'Copia de Precálculo - Stewart, Redlin, Watson - 6a Ed.pdf'
# 'Copia de RESPUESTAS S11-B.gdoc'
# 'DATOS CURIOSOS E INSPIRACIÓN DE VÍCTOR HUGO.gslides'
# 'ddo-scib-bix - 10 dic 2022.gjam'
# 'ddo-scib-bix - 10 dic 2022.pdf'
# 'Dictado Redes.gdoc'
# 'DOC-20230918-WA0040. (1).pdf'
#  DOC-20230918-WA0040..pdf
#  DOC-20250228-WA0087_.pdf
# 'Documento Cancelacion.gdoc'
# 'DOCUMENTOS IMPORANTES POR SI LAS MOSCAS'
# 'Documento sin título (1).gdoc'
# 'Documento sin título (2).gdoc'
# 'Documento sin título (3).gdoc'
# 'Documento sin título (4).gdoc'
# 'Documento sin título (5).gdoc'
# 'Documento sin título.gdoc'
# 'EdD&AdA_B1_Taller1_2221931_JUAN DAVID VANEGAS (1).zip'
# 'EdD&AdA_B1_Taller1_2221931_JUAN DAVID VANEGAS.zip'
# 'Exposicion Biologia.gslides'
#  exposicion.gdoc
# 'Formato consentimiento.gdoc'
#  Formato-Matricula.pdf
#  Fotos
# 'Funciones Quimicas.jpg'
#  Grafos.zip
# 'Habilidad Atencion al Detalle.gdoc'
# 'Hoja de cálculo sin título.gsheet'
#  ICFESS
#  IMG_20200507_084629.jpg
#  IMG_20240411_104944926.jpg
#  IMG_20240411_104948301.jpg
# 'Infografia carbon.gdoc'
#  INFORME_DE_LABORATORIO_2021.docx
# 'INFORME QUIMICA.docx'
# 'INFORME QUIMICA.gdoc'
# 'Jam sin título.gjam'
# 'Jam sin título.pdf'
# 'JUAN DAVID VANEGAS 2221931.sql'
# 'Laboratorio_6_Experisiones_Regulares (1).ipynb'
# 'La Revolución Industrial 4.gdoc'
#  Libros
# 'Los efectos de la implementación de la IA en la industria bancaria Colombiana entre 2017-2022.docx'
#  MAGNITUDES_FISICAS_Y_CONVERSION_DE_UNIDA.pdf
# 'Mapa de Los Sueños.gjam'
# 'Mapa de Los Sueños.pdf'
# 'Marco Teorico.gdoc'
# 'New Folder'
# 'Notas Juan David para SU FUCKING EXPOSICION.gdoc'
#  pacman.ipynb
#  parquea.mp3
# 'Pensamiento Sismetico.gdoc'
# 'Plantilla C2 Entrega 1B Parte 1 - Requerimientos Funcionales y Casos de Uso.docx'
#  poligrafo2023-1.pdf
#  poligrafo2024-2.pdf
#  poligrafo.pdf
# 'Presentación sin título (1).gslides'
# 'Presentación sin título.gslides'
# 'Programacion Libros'
# 'Propuesta pilar.docx'
#  Proyecto-Ambiental.docx
# 'Proyecto de Vida.gjam'
# 'Proyecto de Vida.pdf'
#  ProyectoMachineLearning.ipynb
# 'Que Explicar .gdoc'
# 'Respuestas a las Preguntas Cortas.gdoc'
# 'Semillero Notas.gdoc'
# 'SERIES PELICULAS Y ANIME PARA VERME (1).gdoc'
# 'SERIES PELICULAS Y ANIME PARA VERME.gdoc'
# 'Sistema automático de riego basado en la temperatura.gslides'
# 'Sistema de riego.gdoc'
#  sistema-digestivo-anatomia-y-fisiologia.pptx
# 'SOCIALES CUADRO.gdoc'
#  tabla_resultados.gsheet
#  Taller3.pdf
# 'Tareas 2019.gsheet'
# 'TIK TOK EDUCACION FISICA.mp4'
# 'tkq-ccus-ibo - 20 abr 2021.gjam'
# 'tkq-ccus-ibo - 20 abr 2021.pdf'
# 'Trabajo Direccion Empresarial.gdoc'
# 'TRABAJO QUIMICA.pdf'
#  vampi.robix
#  venta.sql.zip
#  VID_20200818_075720.mp4
#  video..mp4
# Requirement already satisfied: import-ipynb in /usr/local/lib/python3.11/dist-packages (0.2)
# Requirement already satisfied: IPython in /usr/local/lib/python3.11/dist-packages (from import-ipynb) (7.34.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.11/dist-packages (from import-ipynb) (5.10.4)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from IPython->import-ipynb) (75.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/dist-packages (from IPython->import-ipynb) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from IPython->import-ipynb) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from IPython->import-ipynb) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.11/dist-packages (from IPython->import-ipynb) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from IPython->import-ipynb) (3.0.50)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from IPython->import-ipynb) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from IPython->import-ipynb) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from IPython->import-ipynb) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from IPython->import-ipynb) (4.9.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat->import-ipynb) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.11/dist-packages (from nbformat->import-ipynb) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.11/dist-packages (from nbformat->import-ipynb) (5.7.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->IPython->import-ipynb) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->import-ipynb) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->import-ipynb) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->import-ipynb) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->import-ipynb) (0.24.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from jupyter-core!=5.0.*,>=4.12->nbformat->import-ipynb) (4.3.7)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->IPython->import-ipynb) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->import-ipynb) (0.2.13)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from referencing>=0.28.4->jsonschema>=2.6->nbformat->import-ipynb) (4.13.1)
# /content/drive/MyDrive/Colab Notebooks/Trabajos U
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
#  2024_1_Automatas_Lenguajes_Formales
# '2.-GFPI-F-019 Guías de Aprendizaje.docx'
# '4 Matemáticas 2021 (1).gdoc'
# '4 Matemáticas 2021.gdoc'
#  Ambiental.gdoc
# 'Análisis del Macroentorno.docx'
# 'Análisis del Macroentorno.gdoc'
# 'Base de datos.gdoc'
#  Ciclotrón.gslides
# 'Colab Notebooks'
#  comprobante.pdf
# 'contraseñas plataforma integra.gdoc'
#  convocatoria.png
# 'Copia de calculo escencial.pdf'
# 'Copia de Documento Cancelacion.gdoc'
# 'Copia de Precálculo - Stewart, Redlin, Watson - 6a Ed.pdf'
# 'Copia de RESPUESTAS S11-B.gdoc'
# 'DATOS CURIOSOS E INSPIRACIÓN DE VÍCTOR HUGO.gslides'
# 'ddo-scib-bix - 10 dic 2022.gjam'
# 'ddo-scib-bix - 10 dic 2022.pdf'
# 'Dictado Redes.gdoc'
# 'DOC-20230918-WA0040. (1).pdf'
#  DOC-20230918-WA0040..pdf
#  DOC-20250228-WA0087_.pdf
# 'Documento Cancelacion.gdoc'
# 'DOCUMENTOS IMPORANTES POR SI LAS MOSCAS'
# 'Documento sin título (1).gdoc'
# 'Documento sin título (2).gdoc'
# 'Documento sin título (3).gdoc'
# 'Documento sin título (4).gdoc'
# 'Documento sin título (5).gdoc'
# 'Documento sin título.gdoc'
# 'EdD&AdA_B1_Taller1_2221931_JUAN DAVID VANEGAS (1).zip'
# 'EdD&AdA_B1_Taller1_2221931_JUAN DAVID VANEGAS.zip'
# 'Exposicion Biologia.gslides'
#  exposicion.gdoc
# 'Formato consentimiento.gdoc'
#  Formato-Matricula.pdf
#  Fotos
# 'Funciones Quimicas.jpg'
#  Grafos.zip
# 'Habilidad Atencion al Detalle.gdoc'
# 'Hoja de cálculo sin título.gsheet'
#  ICFESS
#  IMG_20200507_084629.jpg
#  IMG_20240411_104944926.jpg
#  IMG_20240411_104948301.jpg
# 'Infografia carbon.gdoc'
#  INFORME_DE_LABORATORIO_2021.docx
# 'INFORME QUIMICA.docx'
# 'INFORME QUIMICA.gdoc'
# 'Jam sin título.gjam'
# 'Jam sin título.pdf'
# 'JUAN DAVID VANEGAS 2221931.sql'
# 'Laboratorio_6_Experisiones_Regulares (1).ipynb'
# 'La Revolución Industrial 4.gdoc'
#  Libros
# 'Los efectos de la implementación de la IA en la industria bancaria Colombiana entre 2017-2022.docx'
#  MAGNITUDES_FISICAS_Y_CONVERSION_DE_UNIDA.pdf
# 'Mapa de Los Sueños.gjam'
# 'Mapa de Los Sueños.pdf'
# 'Marco Teorico.gdoc'
# 'New Folder'
# 'Notas Juan David para SU FUCKING EXPOSICION.gdoc'
#  pacman.ipynb
#  parquea.mp3
# 'Pensamiento Sismetico.gdoc'
# 'Plantilla C2 Entrega 1B Parte 1 - Requerimientos Funcionales y Casos de Uso.docx'
#  poligrafo2023-1.pdf
#  poligrafo2024-2.pdf
#  poligrafo.pdf
# 'Presentación sin título (1).gslides'
# 'Presentación sin título.gslides'
# 'Programacion Libros'
# 'Propuesta pilar.docx'
#  Proyecto-Ambiental.docx
# 'Proyecto de Vida.gjam'
# 'Proyecto de Vida.pdf'
#  ProyectoMachineLearning.ipynb
# 'Que Explicar .gdoc'
# 'Respuestas a las Preguntas Cortas.gdoc'
# 'Semillero Notas.gdoc'
# 'SERIES PELICULAS Y ANIME PARA VERME (1).gdoc'
# 'SERIES PELICULAS Y ANIME PARA VERME.gdoc'
# 'Sistema automático de riego basado en la temperatura.gslides'
# 'Sistema de riego.gdoc'
#  sistema-digestivo-anatomia-y-fisiologia.pptx
# 'SOCIALES CUADRO.gdoc'
#  tabla_resultados.gsheet
#  Taller3.pdf
# 'Tareas 2019.gsheet'
# 'TIK TOK EDUCACION FISICA.mp4'
# 'tkq-ccus-ibo - 20 abr 2021.gjam'
# 'tkq-ccus-ibo - 20 abr 2021.pdf'
# 'Trabajo Direccion Empresarial.gdoc'
# 'TRABAJO QUIMICA.pdf'
#  vampi.robix
#  venta.sql.zip
#  VID_20200818_075720.mp4
#  video..mp4
# Requirement already satisfied: import-ipynb in /usr/local/lib/python3.11/dist-packages (0.2)
# Requirement already satisfied: IPython in /usr/local/lib/python3.11/dist-packages (from import-ipynb) (7.34.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.11/dist-packages (from import-ipynb) (5.10.4)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from IPython->import-ipynb) (75.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/dist-packages (from IPython->import-ipynb) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from IPython->import-ipynb) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from IPython->import-ipynb) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.11/dist-packages (from IPython->import-ipynb) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from IPython->import-ipynb) (3.0.50)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from IPython->import-ipynb) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from IPython->import-ipynb) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from IPython->import-ipynb) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from IPython->import-ipynb) (4.9.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat->import-ipynb) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.11/dist-packages (from nbformat->import-ipynb) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.11/dist-packages (from nbformat->import-ipynb) (5.7.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->IPython->import-ipynb) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->import-ipynb) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->import-ipynb) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->import-ipynb) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->import-ipynb) (0.24.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from jupyter-core!=5.0.*,>=4.12->nbformat->import-ipynb) (4.3.7)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->IPython->import-ipynb) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->import-ipynb) (0.2.13)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from referencing>=0.28.4->jsonschema>=2.6->nbformat->import-ipynb) (4.13.1)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-fae692353d34> in <cell line: 0>()
#      15 import Proyecto2  # Importar funciones desde Proyecto2.ipynb
#      16 import Proyecto3  # Importar funciones desde Proyecto3.ipynb
# ---> 17 import Proyecto4
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /usr/local/lib/python3.11/dist-packages/import_ipynb.py in exec_module(self, mod)
#      62                     )
#      63                     # run the code in themodule
# ---> 64                     exec(code, mod.__dict__)
#      65         finally:
#      66             self.shell.user_ns = save_user_ns
#
# <string> in <module>
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2416                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2417             with self.builtin_trap:
# -> 2418                 result = fn(*args, **kwargs)
#    2419             return result
#    2420
#
# <decorator-gen-85> in cd(self, parameter_s)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/magics/osm.py in cd(self, parameter_s)
#     413             else:
#     414                 cwd = os.getcwd()
# --> 415                 dhist = self.shell.user_ns['_dh']
#     416                 if oldcwd != cwd:
#     417                     dhist.append(cwd)
#
# KeyError: '_dh'
